# %%
from sqlalchemy import create_engine
import pandas as pd
import pymysql

# %%
books = pd.read_csv('LibBooks.csv')
members = pd.read_csv('LibMems.csv')

# %%
USER = 'kctey'
PASSWORD = 'CQu1FxSp'
HOST = '127.0.0.1'
PORT = 3306
DATABASE = 'Library'

engine = create_engine('mysql+pymysql://{0}:{1}@{2}:{3}/{4}'.format(
        USER, PASSWORD, HOST, PORT, DATABASE
))
cursor = engine.connect()

# %%
sql_statement = 'select * from member_test'

table_df = pd.read_sql(
    sql_statement,
    con=engine
)
table_df
# Out:
#   ﻿memberid              name      faculty  phone number  \
# 0     A101A  Hermione Granger      Science      33336663
# 1     A201B   Sherlock Holmes          Law      44327676
# 2     A301C            Tintin  Engineering      14358788
# 3     A401D    Prinche Hamlet         FASS      16091609
# 4    A5101E       Willy Wonka         FASS      19701970
# 5     A601F   Holly Golightly     Business      55548008
# 6     A701G       Raskolnikov          Law      18661866
# 7     A801H   Patrick Bateman     Business      38548544
# 8     A901I      Captain Ahab      Science      18511851
#
#            email address
# 0         flying@als.edu
# 1  elementarydrw@als.edu
# 2        luvmilu@als.edu
# 3      tobeornot@als.edu
# 4         choco1@als.edu
# 5        diamond@als.edu
# 6         oneaxe@als.edu
# 7           mice@als.edu
# 8         wwhale@als.edu
